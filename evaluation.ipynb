# %% [markdown]
# # 4.1
# Es ist schwierig zu sagen, welche Felder jetzt am aussagekräftigsten waren, aber ich würde sagen, es waren diese Felder: session_duration, threat_level und failed_attempts.

# %% [markdown]
# # 4.2
#
# Ich habe mit folgendem Code herausgefunden, welche Spalten am wichtigsten für mein Modell waren:
#
# ![image.png](attachment:image.png)
#
#
# Das hier war die Ausgabe:
#
# ![image-2.png](attachment:image-2.png)
#
# Wie man sieht, lagen meine Vermutungen alle in den Top 4. Ich hätte aber nicht erwartet, dass Success so viel Einfluss in die Vorhersage hat, sogar mehr als failed_attempts und threat_level zusammen.
#
# Der Code dazu ist in <b>data_description.ipynb<b>

# %% [markdown]
# # 4.3
#
# ![image.png](attachment:image.png)
#
# Hier habe ich die Sensitivität und die Spezifität berechnet. Man sieht, dass die Sensivität sehr gering ist und nur ca. die Hälfte der echten positiven Fälle erkennt werden. Die Spezifität ist viel höher. Das heisst, mein Modell erkennt die negativen Fälle ziemlich gut und gibt nicht so häufig falschen Alarm.
#
# Der richtige Code ist in <b>data_description.ipynb<b> zu finden.

# %% [markdown]
# # 4.4
# Allgemein ist mein Modell nicht schlecht, aber auch nicht wirklich gut. In der realität würde es viele Anmeldeversuche, die geblockt werden müssten, nicht blocken, da die Sensitivität sehr tief ist. Deshalb wäre mein Modell für den richtigen Einsatz nicht effektiv.
# Ich denke, der Grund ist, dass die Daten nicht ganz ausgereicht haben und in der Wirklichkeit noch andere Faktoren mitspielen. Zudem konnte ich nicht alle Spalten verwenden, weil ich dann immer einen Memory-Error bekommen habe. Mit mehr Daten hätte man das Modell vermutlich noch ein wenig verbessern können.
